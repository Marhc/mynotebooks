# %% [markdown]
# # Usando Matplotlib

# %%
# importando o pacote
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Gráfico de Linha

# %%
# Dados para as coordenadas do gráfico
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de linha')

plt.show()

# %% [markdown]
# ## 2. Gráfico de Barras

# %%
# Dados para as barras
categorias = ['Categoria 1', 'Categoria 2', 'Categoria 3']
valores = [10, 20, 30]

plt.bar(categorias, valores)
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.title('Gráfico de barra')

plt.show()

# %% [markdown]
# ## 3. Gráfico de Pizza (ou Torta)

# %%
# Dados para as fatias
categorias = ['Categoria 1', 'Categoria 2', 'Categoria 3']
valores = [10, 20, 30]

plt.pie(valores, labels=categorias)
plt.title('Gráfico de pizza')

plt.show()

# %% [markdown]
# ## 4. Gráfico de Dispersão

# %%
# Dados para as coordenadas
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.scatter(x, y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de dispersão')

plt.grid()
